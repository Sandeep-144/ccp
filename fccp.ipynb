# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder, PolynomialFeatures
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, roc_curve, auc
from imblearn.over_sampling import SMOTE

# %%
df = pd.read_csv("Customer Churn.csv")

# %%
df.shape
# Out:
# (3150, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3150 entries, 0 to 3149
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Call  Failure            3150 non-null   int64
#  1   Complains                3150 non-null   int64
#  2   Subscription  Length     3150 non-null   int64
#  3   Charge  Amount           3150 non-null   int64
#  4   Seconds of Use           3150 non-null   int64
#  5   Frequency of use         3150 non-null   int64
#  6   Frequency of SMS         3150 non-null   int64
#  7   Distinct Called Numbers  3150 non-null   int64
#  8   Age Group                3150 non-null   int64
#  9   Tariff Plan              3150 non-null   int64
#  10  Status                   3150 non-null   int64
#  11  Age                      3150 non-null   int64
#  12  Customer Value           3150 non-null   float64
#  13  Churn                    3150 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 344.7 KB

# %%
df.isnull().sum()
# Out:
# Call  Failure              0
# Complains                  0
# Subscription  Length       0
# Charge  Amount             0
# Seconds of Use             0
# Frequency of use           0
# Frequency of SMS           0
# Distinct Called Numbers    0
# Age Group                  0
# Tariff Plan                0
# Status                     0
# Age                        0
# Customer Value             0
# Churn                      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 300

# %%
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# 0

# %%
# Drop irrelevant columns
df = df.drop(columns=['Age'])

# %%
df['Churn'].value_counts()
# Out:
# Churn
# 0    2404
# 1     446
# Name: count, dtype: int64

# %%
# Churn distribution visualization
plt.figure(figsize=(5, 3))
sns.countplot(x='Churn', data=df, palette='coolwarm')
plt.title("Customer Churn Distribution")
plt.show()
# Out:
# C:\Users\maliv\AppData\Local\Temp\ipykernel_8640\2807788532.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Churn', data=df, palette='coolwarm')

# %%
# Feature correlation heatmap
plt.figure(figsize=(12, 6))
sns.heatmap(df.corr(), annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Feature Correlation Heatmap")
plt.show()

# %%
# Check categorical feature distributions
categorical_cols = ['Tariff Plan', 'Status', 'Age Group']
for col in categorical_cols:
    print(f"\n{col} Value Counts:\n", df[col].value_counts())

# Clean column names (remove spaces)
df.columns = df.columns.str.strip()
# Out:
# Tariff Plan Value Counts:
#  Tariff Plan
# 1    2621
# 2     229
# Name: count, dtype: int64
#
# Status Value Counts:
#  Status
# 1    2166
# 2     684
# Name: count, dtype: int64
#
# Age Group Value Counts:
#  Age Group
# 3    1296
# 2     921
# 4     367
# 5     154
# 1     112
# Name: count, dtype: int64

# %%
# Boxplot to detect outliers
plt.figure(figsize=(12, 6))
sns.boxplot(data=df, palette="coolwarm")
plt.xticks(rotation=90)
plt.title("Feature Boxplots for Outlier Detection")
plt.show()

# %%
df.columns
# Out:
# Index(['Call  Failure', 'Complains', 'Subscription  Length', 'Charge  Amount',
#        'Seconds of Use', 'Frequency of use', 'Frequency of SMS',
#        'Distinct Called Numbers', 'Age Group', 'Tariff Plan', 'Status',
#        'Customer Value', 'Churn'],
#       dtype='object')

# %%
df.rename(columns={'Subscription  Length': 'Subscription Length'}, inplace=True)

# %%
plt.figure(figsize=(6, 4))
sns.boxplot(x='Churn', y='Subscription Length', data=df, palette='coolwarm')
plt.title("Subscription Length vs Churn")
plt.show()
# Out:
# C:\Users\maliv\AppData\Local\Temp\ipykernel_8640\411644310.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Churn', y='Subscription Length', data=df, palette='coolwarm')

# %%
plt.figure(figsize=(6, 4))
sns.boxplot(x='Churn', y='Charge  Amount', data=df, palette='coolwarm')
plt.title("Charge Amount vs Churn")
plt.show()
# Out:
# C:\Users\maliv\AppData\Local\Temp\ipykernel_8640\2180001320.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Churn', y='Charge  Amount', data=df, palette='coolwarm')

# %%
plt.figure(figsize=(6, 4))
sns.countplot(x='Age Group', hue='Churn', data=df, palette='coolwarm')
plt.title("Age Group vs Churn")
plt.show()

# %%
df['Churn'].value_counts()
# Out:
# Churn
# 0    2404
# 1     446
# Name: count, dtype: int64

# %%
# Outlier removal using IQR
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1
columns_to_check = df.columns[df.columns != 'Churn']
df = df[~((df[columns_to_check] < (Q1[columns_to_check] - 3.0 * IQR[columns_to_check])) | 
          (df[columns_to_check] > (Q3[columns_to_check] + 3.0 * IQR[columns_to_check]))).any(axis=1)]

# %%
df['Churn'].value_counts()
# Out:
# Churn
# 0    1635
# 1      64
# Name: count, dtype: int64

# %%
# Feature Engineering - Polynomial Features
feature_cols = ['Subscription Length', 'Charge  Amount', 'Seconds of Use', 'Frequency of use', 'Customer Value']
poly = PolynomialFeatures(degree=2, interaction_only=True, include_bias=False)
X_poly = poly.fit_transform(df[feature_cols])
df_poly = pd.DataFrame(X_poly, columns=poly.get_feature_names_out(feature_cols))
df = pd.concat([df, df_poly], axis=1)

# %%
# Log transformation for skewed data
df['Seconds of Use'] = np.log1p(df['Seconds of Use'])

# %%
# Function to plot distributions
def plot_distribution(col):
    plt.figure(figsize=(6, 4))
    sns.histplot(df[col], kde=True, bins=30)
    plt.title(f"Distribution of {col}")
    plt.show()

# Plot distributions
for col in feature_cols:
    plot_distribution(col)

# %%
# Convert categorical variables to numeric
label_encoders = {}
for col in ['Tariff Plan', 'Status', 'Age Group']:
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col])
    label_encoders[col] = le

# %%
# Define features and target
X = df.drop(columns=['Churn'])
y = df['Churn']

# %%
# Fill missing values
X.fillna(X.median(), inplace=True)
y.fillna(y.median(), inplace=True)

# %%
# Split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# Handle class imbalance using SMOTE
if len(np.unique(y_train)) > 1:
    smote = SMOTE(random_state=42)
    X_train, y_train = smote.fit_resample(X_train, y_train)

# Feature Scaling
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
# ANN Model
model = Sequential([
    Dense(64, activation='relu', input_shape=(X_train.shape[1],)),
    Dropout(0.3),
    Dense(32, activation='relu'),
    Dropout(0.2),
    Dense(1, activation='sigmoid')
])
# Out:
# C:\Users\maliv\AppData\Roaming\Python\Python312\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Compile model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
# Train model
history = model.fit(X_train, y_train, epochs=50, batch_size=16, validation_data=(X_test, y_test))
# Out:
# Epoch 1/50
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7291 - loss: 0.5497 - val_accuracy: 0.8714 - val_loss: 0.2577
# Epoch 2/50
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9115 - loss: 0.2386 - val_accuracy: 0.9179 - val_loss: 0.1805
# Epoch 3/50
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9316 - loss: 0.1973 - val_accuracy: 0.9357 - val_loss: 0.1518
# Epoch 4/50
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9422 - loss: 0.1729 - val_accuracy: 0.9343 - val_loss: 0.1511
# Epoch 5/50
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9641 - loss: 0.1182 - val_accuracy: 0.9494 - val_loss: 0.1161
# Epoch 6/50
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9704 - loss: 0.1089 - val_accuracy: 0.9480 - val_loss: 0.1245
# Epoch 7/50
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9721 - loss: 0.0965 - val_accuracy: 0.9549 - val_loss: 0.1162
# Epoch 8/50
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9736 - loss: 0.0763 - val_accuracy: 0.9631 - val_loss: 0.1029
# Epoch 9/50
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9857 - loss: 0.0585 - val_accuracy: 0.9713 - val_loss: 0.0971
# Epoch 10/50
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9876 - loss: 0.0476 - val_accuracy: 0.9672 - val_loss: 0.1085
# Epoch 11/50
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9869 - loss: 0.0545 - val_accuracy: 0.9699 - val_loss: 0.0997
# Epoch 12/50
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9806 - loss: 0.0581 - val_accuracy: 0.9740 - val_loss: 0.1048
# Epoch 13/50
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9842 - loss: 0.0505 - val_accuracy: 0.9713 - val_loss: 0.1204
# Epoch 14/50
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9893 - loss: 0.0352 - val_accuracy: 0.9781 - val_loss: 0.1066
# Epoch 15/50
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9918 - loss: 0.0323 - val_accuracy: 0.9740 - val_loss: 0.1195
# Epoch 16/50
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9937 - loss: 0.0318 - val_accuracy: 0.9726 - val_loss: 0.1035
# Epoch 17/50
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9906 - loss: 0.0335 - val_accuracy: 0.9781 - val_loss: 0.1191
# Epoch 18/50
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9875 - loss: 0.0372 - val_accuracy: 0.9781 - val_loss: 0.1174
# Epoch 19/50
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9956 - loss: 0.0234 - val_accuracy: 0.9795 - val_loss: 0.1153
# Epoch 20/50
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9920 - loss: 0.0378 - val_accuracy: 0.9699 - val_loss: 0.1354
# Epoch 21/50
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9948 - loss: 0.0179 - val_accuracy: 0.9754 - val_loss: 0.1241
# Epoch 22/50
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9952 - loss: 0.0185 - val_accuracy: 0.9740 - val_loss: 0.1202
# Epoch 23/50
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9969 - loss: 0.0162 - val_accuracy: 0.9767 - val_loss: 0.1279
# Epoch 24/50
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9943 - loss: 0.0233 - val_accuracy: 0.9808 - val_loss: 0.1198
# Epoch 25/50
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9923 - loss: 0.0239 - val_accuracy: 0.9767 - val_loss: 0.1302
# Epoch 26/50
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9942 - loss: 0.0182 - val_accuracy: 0.9767 - val_loss: 0.1287
# Epoch 27/50
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9928 - loss: 0.0256 - val_accuracy: 0.9795 - val_loss: 0.1356
# Epoch 28/50
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9915 - loss: 0.0309 - val_accuracy: 0.9767 - val_loss: 0.1398
# Epoch 29/50
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9963 - loss: 0.0129 - val_accuracy: 0.9795 - val_loss: 0.1369
# Epoch 30/50
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9947 - loss: 0.0189 - val_accuracy: 0.9808 - val_loss: 0.1487
# Epoch 31/50
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9931 - loss: 0.0222 - val_accuracy: 0.9781 - val_loss: 0.1389
# Epoch 32/50
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9969 - loss: 0.0143 - val_accuracy: 0.9795 - val_loss: 0.1450
# Epoch 33/50
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9953 - loss: 0.0158 - val_accuracy: 0.9781 - val_loss: 0.1502
# Epoch 34/50
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9970 - loss: 0.0140 - val_accuracy: 0.9795 - val_loss: 0.1516
# Epoch 35/50
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9903 - loss: 0.0323 - val_accuracy: 0.9781 - val_loss: 0.1586
# Epoch 36/50
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9957 - loss: 0.0173 - val_accuracy: 0.9795 - val_loss: 0.1510
# Epoch 37/50
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9945 - loss: 0.0183 - val_accuracy: 0.9781 - val_loss: 0.1587
# Epoch 38/50
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9971 - loss: 0.0106 - val_accuracy: 0.9795 - val_loss: 0.1677
# Epoch 39/50
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9966 - loss: 0.0121 - val_accuracy: 0.9767 - val_loss: 0.1570
# Epoch 40/50
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9969 - loss: 0.0120 - val_accuracy: 0.9795 - val_loss: 0.1566
# Epoch 41/50
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9917 - loss: 0.0184 - val_accuracy: 0.9781 - val_loss: 0.1712
# Epoch 42/50
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9959 - loss: 0.0178 - val_accuracy: 0.9781 - val_loss: 0.1602
# Epoch 43/50
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9976 - loss: 0.0118 - val_accuracy: 0.9781 - val_loss: 0.1701
# Epoch 44/50
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9983 - loss: 0.0090 - val_accuracy: 0.9808 - val_loss: 0.1698
# Epoch 45/50
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9960 - loss: 0.0123 - val_accuracy: 0.9795 - val_loss: 0.1759
# Epoch 46/50
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9938 - loss: 0.0396 - val_accuracy: 0.9822 - val_loss: 0.1662
# Epoch 47/50
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9944 - loss: 0.0140 - val_accuracy: 0.9781 - val_loss: 0.1771
# Epoch 48/50
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9962 - loss: 0.0167 - val_accuracy: 0.9795 - val_loss: 0.1884
# Epoch 49/50
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9961 - loss: 0.0163 - val_accuracy: 0.9767 - val_loss: 0.1864
# Epoch 50/50
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9969 - loss: 0.0239 - val_accuracy: 0.9808 - val_loss: 0.1851

# %%
# Plot training history
plt.figure(figsize=(10, 4))
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.legend()
plt.title("Model Accuracy")
plt.show()

plt.figure(figsize=(10, 4))
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend()
plt.title("Model Loss")
plt.show()

# %%
# Model Evaluation
y_pred = (model.predict(X_test) > 0.5).astype("int32")
print("Classification Report:\n", classification_report(y_test, y_pred))
print("Accuracy Score:", accuracy_score(y_test, y_pred))
# Out:
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.99      0.99      0.99       716
#          1.0       0.53      0.53      0.53        15
#
#     accuracy                           0.98       731
#    macro avg       0.76      0.76      0.76       731
# weighted avg       0.98      0.98      0.98       731
#
# Accuracy Score: 0.9808481532147743

# %%
# Confusion Matrix
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(5, 3))
sns.heatmap(cm, annot=True, fmt='d', cmap='coolwarm', xticklabels=['No Churn', 'Churn'], yticklabels=['No Churn', 'Churn'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %%
# ROC Curve
y_prob = model.predict(X_test)
fpr, tpr, _ = roc_curve(y_test, y_prob)
roc_auc = auc(fpr, tpr)
plt.figure(figsize=(6, 4))
plt.plot(fpr, tpr, label=f'ROC curve (area = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend()
plt.show()
# Out:
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %%
# Display Model Summary
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_3 (Dense)                 │ (None, 64)             │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 11,717 (45.77 KB)
#  Trainable params: 3,905 (15.25 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 7,812 (30.52 KB)

# %%
for i, layer in enumerate(model.layers):
    print(f"Layer {i+1}: {layer.name} | Type: {layer.__class__.__name__} | Output Shape: {layer.output.shape} | Params: {layer.count_params()}")
# Out:
# Layer 1: dense_3 | Type: Dense | Output Shape: (None, 64) | Params: 1792
# Layer 2: dropout_2 | Type: Dropout | Output Shape: (None, 64) | Params: 0
# Layer 3: dense_4 | Type: Dense | Output Shape: (None, 32) | Params: 2080
# Layer 4: dropout_3 | Type: Dropout | Output Shape: (None, 32) | Params: 0
# Layer 5: dense_5 | Type: Dense | Output Shape: (None, 1) | Params: 33

# %%
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.99      0.99      0.99       716
#          1.0       0.53      0.53      0.53        15
#
#     accuracy                           0.98       731
#    macro avg       0.76      0.76      0.76       731
# weighted avg       0.98      0.98      0.98       731

# %%
model.save("churn_f_model.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
model.save("churn_f_model.keras")

# %%
import joblib

# Save scaler, label encoders, and feature column order
joblib.dump(scaler, "f_scaler.pkl")
joblib.dump(label_encoders, "f_label_encoders.pkl")
joblib.dump(X.columns.tolist(), "f_X_columns.pkl")
# Out:
# ['f_X_columns.pkl']

# %%
from sklearn.preprocessing import PolynomialFeatures
import joblib

poly = PolynomialFeatures(degree=2, interaction_only=True, include_bias=False)
X_poly = poly.fit_transform(X_train)

# Save the transformer
joblib.dump(poly, 'f_poly_transformer.pkl')

# Also save feature names if needed
joblib.dump(poly.get_feature_names_out(input_features=X.columns), 'f_poly_features.pkl')
# Out:
# ['f_poly_features.pkl']
